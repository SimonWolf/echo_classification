# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
import pathlib
import numpy as np
import os
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
data_dir = pathlib.Path("data")
list_ds = tf.data.Dataset.list_files(str(data_dir/'*/*.png'))
CLASS_NAMES = np.array([item.name for item in data_dir.glob('*') if item.name != ".DS_Store"])
image_count = len(list(data_dir.glob('*/*.png')))

# %%
CLASS_NAMES
# Out:
# array(['schlafzimmer', 'kueche', 'klo', 'wohnzimmer'], dtype='<U12')

# %%
BATCH_SIZE = 8
IMG_HEIGHT = 400
IMG_WIDTH = 400
STEPS_PER_EPOCH = np.ceil(image_count/BATCH_SIZE)

# %%
def get_label(file_path):
    # convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    # The second to last is the class-directory
    return parts[-2] == CLASS_NAMES
def decode_img(img):
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_png(img)
    # Use `convert_image_dtype` to convert to floats in the [0,1] range.
    img = tf.image.convert_image_dtype(img, tf.float32)
    # resize the image to the desired size.
    return tf.image.resize(img, [IMG_WIDTH, IMG_HEIGHT])

def process_path(file_path):
    label = get_label(file_path)
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
    # This is a small dataset, only load it once, and keep it in memory.
    # use `.cache(filename)` to cache preprocessing work for datasets that don't
    # fit in memory.
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    # Repeat forever
    ds = ds.repeat()

    ds = ds.batch(16)

    # `prefetch` lets the dataset fetch batches in the background while the model
    # is training.
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

# %%
full_dataset  = list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
#train_ds = prepare_for_training(full_dataset)
#full_dataset = (full_dataset.map(normalize).shuffle(50000).batch(128, drop_remainder=True))#
#
train_dataset = prepare_for_training(full_dataset.take(int(image_count*0.6)))
test_dataset = prepare_for_training(full_dataset.skip(int(image_count*0.6)))

# %%
for image, label in train_dataset.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
    print("Label: ", label.numpy().shape)
# Out:
# Image shape:  (16, 400, 400, 1)
# Label:  [[False False  True False]
#  [False  True False False]
#  [False False False  True]
#  [False False False  True]
#  [ True False False False]
#  [False False  True False]
#  [False False False  True]
#  [ True False False False]
#  [ True False False False]
#  [False  True False False]
#  [False False  True False]
#  [ True False False False]
#  [False  True False False]
#  [False False  True False]
#  [ True False False False]
#  [ True False False False]]
# Label:  (16, 4)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense,Dropout

model = Sequential([
    Conv2D(8, 3, padding='same', activation='relu', input_shape=(400, 400,1),name="inputlayer"),
    MaxPooling2D(),
    Conv2D(16, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(32, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(128, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Conv2D(256, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.2),
    Conv2D(128, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.3),
    Conv2D(64, 3, padding='same', activation='relu'),
    MaxPooling2D(),
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.1),
    Dense(4, activation='softmax', name='output')
])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inputlayer (Conv2D)          (None, 400, 400, 8)       80
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 200, 200, 8)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 200, 200, 16)      1168
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 100, 100, 16)      0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 100, 100, 32)      4640
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 50, 50, 64)        18496
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 25, 25, 128)       73856
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 12, 12, 256)       295168
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 6, 6, 256)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 6, 6, 256)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 6, 6, 128)         295040
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 3, 3, 128)         0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 3, 3, 128)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 3, 3, 64)          73792
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               16640
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# output (Dense)               (None, 4)                 1028
# =================================================================
# Total params: 779,908
# Trainable params: 779,908
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
        optimizer='adam',
        loss=['categorical_crossentropy'],
        metrics=['accuracy']
    )

# %%
history=model.fit(train_dataset,epochs=25,validation_data=test_dataset,steps_per_epoch=10,validation_steps=20)
# Out:
# Train for 10 steps, validate for 20 steps
# Epoch 1/25
# 10/10 [==============================] - 18s 2s/step - loss: 1.3886 - accuracy: 0.2188 - val_loss: 1.3908 - val_accuracy: 0.2406
# Epoch 2/25
# 10/10 [==============================] - 17s 2s/step - loss: 1.3813 - accuracy: 0.2688 - val_loss: 1.3652 - val_accuracy: 0.2344
# Epoch 3/25
# 10/10 [==============================] - 16s 2s/step - loss: 1.3698 - accuracy: 0.2625 - val_loss: 1.3811 - val_accuracy: 0.2906
# Epoch 4/25
# 10/10 [==============================] - 17s 2s/step - loss: 1.3834 - accuracy: 0.2500 - val_loss: 1.3756 - val_accuracy: 0.3187
# Epoch 5/25
# 10/10 [==============================] - 16s 2s/step - loss: 1.3036 - accuracy: 0.3250 - val_loss: 1.2576 - val_accuracy: 0.4656
# Epoch 6/25
# 10/10 [==============================] - 16s 2s/step - loss: 1.3017 - accuracy: 0.4688 - val_loss: 1.1923 - val_accuracy: 0.5906
# Epoch 7/25
# 10/10 [==============================] - 16s 2s/step - loss: 1.3735 - accuracy: 0.3375 - val_loss: 1.3229 - val_accuracy: 0.3750
# Epoch 8/25
# 10/10 [==============================] - 16s 2s/step - loss: 1.2069 - accuracy: 0.4812 - val_loss: 0.9829 - val_accuracy: 0.4875
# Epoch 9/25
# 10/10 [==============================] - 16s 2s/step - loss: 1.0971 - accuracy: 0.4313 - val_loss: 1.0691 - val_accuracy: 0.4000
# Epoch 10/25
# 10/10 [==============================] - 16s 2s/step - loss: 0.9199 - accuracy: 0.5562 - val_loss: 0.8571 - val_accuracy: 0.6156
# Epoch 11/25
# 10/10 [==============================] - 17s 2s/step - loss: 0.8115 - accuracy: 0.6000 - val_loss: 0.7447 - val_accuracy: 0.6531
# Epoch 12/25
# 10/10 [==============================] - 16s 2s/step - loss: 0.8220 - accuracy: 0.6062 - val_loss: 0.9171 - val_accuracy: 0.5562
# Epoch 13/25
# 10/10 [==============================] - 16s 2s/step - loss: 0.8903 - accuracy: 0.5688 - val_loss: 0.7717 - val_accuracy: 0.6406
# Epoch 14/25
# 10/10 [==============================] - 16s 2s/step - loss: 0.7362 - accuracy: 0.6687 - val_loss: 0.7343 - val_accuracy: 0.7281
# Epoch 15/25
# 10/10 [==============================] - 16s 2s/step - loss: 0.6634 - accuracy: 0.7000 - val_loss: 0.6252 - val_accuracy: 0.7250
# Epoch 16/25
# 10/10 [==============================] - 16s 2s/step - loss: 0.7779 - accuracy: 0.6562 - val_loss: 0.6158 - val_accuracy: 0.7188
# Epoch 17/25
# 10/10 [==============================] - 16s 2s/step - loss: 0.6005 - accuracy: 0.7063 - val_loss: 0.6104 - val_accuracy: 0.7094
# Epoch 18/25
# 10/10 [==============================] - 16s 2s/step - loss: 0.5545 - accuracy: 0.7437 - val_loss: 0.6415 - val_accuracy: 0.6781
# Epoch 19/25
# 10/10 [==============================] - 17s 2s/step - loss: 0.4774 - accuracy: 0.8125 - val_loss: 0.4614 - val_accuracy: 0.8094
# Epoch 20/25
# 10/10 [==============================] - 16s 2s/step - loss: 0.6116 - accuracy: 0.7563 - val_loss: 0.5805 - val_accuracy: 0.8062
# Epoch 21/25
# 10/10 [==============================] - 16s 2s/step - loss: 0.5332 - accuracy: 0.8188 - val_loss: 0.4756 - val_accuracy: 0.8313
# Epoch 22/25
# 10/10 [==============================] - 16s 2s/step - loss: 0.5700 - accuracy: 0.7875 - val_loss: 0.5178 - val_accuracy: 0.8250
# Epoch 23/25
# 10/10 [==============================] - 16s 2s/step - loss: 0.4812 - accuracy: 0.8188 - val_loss: 0.4658 - val_accuracy: 0.8344
# Epoch 24/25
# 10/10 [==============================] - 16s 2s/step - loss: 0.3796 - accuracy: 0.8687 - val_loss: 0.2527 - val_accuracy: 0.9312
# Epoch 25/25
# 10/10 [==============================] - 17s 2s/step - loss: 0.3973 - accuracy: 0.8500 - val_loss: 0.3791 - val_accuracy: 0.8625

# %%
# Get training and test loss histories
training_loss = history.history['loss']
test_loss = history.history['val_loss']
training_accuracy = history.history['accuracy']
test_accuracy = history.history['val_accuracy']
# Create count of the number of epochs
epoch_count = range(1, len(training_loss) + 1)

# Visualize loss history
plt.figure(figsize=(20,5))
plt.plot(epoch_count, training_loss, 'r--')
plt.plot(epoch_count, test_loss, 'b-')
plt.plot(epoch_count, training_accuracy, 'g--')
plt.plot(epoch_count, test_accuracy, 'y-')
plt.legend(['Training Loss', 'Test Loss','training_accuracy','test_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Loss / Accuracy')
plt.show();

# %%
true=[]
pred=[]

def classnumber(boollabel):
    for i,b in enumerate(boollabel):
        if b:return i

for images, labels in test_dataset.take(5):
    for index,image in enumerate(images):
        pred_temp=model.predict(tf.reshape(image,(1,400,400,1)))[0]
        pred_temp=(pred_temp.max(axis=0,) == pred_temp)
        true_temp=(labels[index].numpy())
        
        true.append(classnumber(true_temp))
        pred.append(classnumber(pred_temp))

# %%
import seaborn as sn
import pandas as pd
df_cm = pd.DataFrame(tf.math.confusion_matrix(true,pred).numpy(), CLASS_NAMES, CLASS_NAMES)
# plt.figure(figsize=(10,7))
sn.set(font_scale=1.4) # for label size
sn.heatmap(df_cm, annot=True, annot_kws={"size": 16},cmap="Blues",fmt="d") # font size

plt.show()

# %% [markdown]
# ## Live Testing

# %%
from PIL import Image
from matplotlib.pyplot import imshow
import os
import glob
import time
import sounddevice as sd
import numpy as np
import time
import librosa

def generate_new_echo(fs=96000,duration=0.1,f=25000):
    time.sleep(1)
    sine = (np.sin(2*np.pi*np.arange(fs*duration)*f/fs)).astype(np.float32)
    samples=np.concatenate((sine, [0]*int(fs*duration)*2), axis=None)
    
    for i in range(2):
        samples=np.concatenate((samples, sine), axis=None)
        samples=np.concatenate((samples, [0]*int(fs*duration*2)), axis=None)


    rec=sd.playrec(samples,fs,channels=1)
    rec=rec.reshape((samples.shape[0]))[60050:87000]
    time.sleep(1)
    return rec


    
def img_from_audio(rec):
    
    D=np.abs(librosa.stft(rec,n_fft=2048,hop_length=64))
    DB=librosa.amplitude_to_db(D,ref=np.max)
    
    
    img=np.interp(DB[250:600,:400], (DB[250:600,:400].min(), DB[250:600,:400].max()), (0, 255))
    img = Image.fromarray(np.uint8(img) , 'L')
    img.save("temp.png")
    return img

# %%
img=img_from_audio(generate_new_echo())

#display(img)
#print(CLASS_NAMES)
img = tf.io.read_file("temp.png")
#img = tf.io.read_file("data/schlafzimmer/100.png")
img = decode_img(img)
print(CLASS_NAMES[np.argmax(model.predict(tf.reshape(img,(1,400,400,1))))])
# Out:
# klo
