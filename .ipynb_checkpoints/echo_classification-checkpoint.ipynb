# %% [markdown]
# # Echo
# ## Idee
# Ähnlich der Echoortung bei Tieren soll ein kurzes Tonsignal gesendet werden. Mit einem Mikrofon wird das Signal und dessen Echo aufgezeichnet. Die Audiosignale soll in Spektrogramme umgewandelt werden, welche anschließend als Trainingsdaten für verschiedene KI-Modelle dienen sollen.
# Mögliche Einsatzgebiete sind:
# - Objektklassifikation
# - Raumklassifikation (aufgrund bestimmter resonanzeigenschaften der Räume)
#
# ## Signal generieren, aufzeichnen und Spektrogram erzeugen
# Wie bereits beschrieben soll ein akustisches Signal generiert werden gleichzeitig das echo aufgenommen werden. Das Signal wird im folgenden bei eine Sample Rate von 96kHz generiert und aufgezeichnet. Die Frequenz des Signals liegt mit 25kHz knapp im Ultraschallbereich. Aufgrund der nicht wirklich geeigneten Laptoplautsprecher hört man zu Beginn und am Ende des Signals ein Knacken. Das Knacken wird auch in der Audiowellendarstellung und im Spektrogramm sichtbar. Abgesehen davon wäre eventuell eine höhere Abtastrate sinnvoll, da das echo ja nur um wenige ms verschoben zurück kommt. Jedoch ist 96kHz die höchste Abtastrate die mein Laptop her gibt.

# %%
import sounddevice as sd
import plotly.graph_objects as go
import numpy as np
import time
import librosa
import librosa.display
from PIL import Image
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
import os
import glob
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-72ef7f0390aa> in <module>
# ----> 1 import sounddevice as sd
#       2 import plotly.graph_objects as go
#       3 import numpy as np
#       4 import time
#       5 import librosa
#
# ImportError: No module named 'sounddevice'

# %%
#sd.query_devices()



sd.default.device =  0,1
time.sleep(0.5)
fs=96000
duration=0.1
f=25000
sine = (np.sin(2*np.pi*np.arange(fs*duration)*f/fs)).astype(np.float32)
samples=np.concatenate((sine, [0]*int(fs*duration)*2), axis=None)
for i in range(2):
    samples=np.concatenate((samples, sine), axis=None)
    samples=np.concatenate((samples, [0]*int(fs*duration*2)), axis=None)


rec=sd.playrec(samples,fs,channels=1)
rec=rec.reshape((samples.shape[0]))[60050:87000]
time.sleep(1)
fig = go.Figure(data=go.Scatter(y=rec,x=np.array(range(len(rec)))/fs))
fig.update_layout(
    title="Aufgenommmenes Audiosignal:",
    xaxis_title="Zeit in s",
    yaxis_title="Signalstärke",
)
fig.show()
# Out:
# <div>
#
#
#             <div id="8214db32-070f-493d-b67d-5aca6148526a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8214db32-070f-493d-b67d-5aca6148526a")) {
#                     Plotly.newPlot(
#                         '8214db32-070f-493d-b67d-5aca6148526a',
#                         [{"type": "scatter", "x": [0.0, 1.0416666666666666e-05, 2.0833333333333333e-05, 3.125e-05, 4.1666666666666665e-05, 5.208333333333334e-05, 6.25e-05, 7.291666666666667e-05, 8.333333333333333e-05, 9.375e-05, 0.00010416666666666667, 0.00011458333333333333, 0.000125, 0.00013541666666666666, 0.00014583333333333335, 0.00015625, 0.00016666666666666666, 0.00017708333333333335, 0.0001875, 0.00019791666666666666, 0.00020833333333333335, 0.00021875, 0.00022916666666666666, 0.00023958333333333332, 0.00025, 0.00026041666666666666, 0.0002708333333333333, 0.00028125, 0.0002916666666666667, 0.00030208333333333335, 0.0003125, 0.00032291666666666666, 0.0003333333333333333, 0.00034375, 0.0003541666666666667, 0.00036458333333333335, 0.000375, 0.00038541666666666667, 0.0003958333333333333, 0.00040625, 0.0004166666666666667, 0.00042708333333333335, 0.0004375, 0.00044791666666666667, 0.0004583333333333333, 0.00046875, 0.00047916666666666664, 0.0004895833333333333, 0.0005, 0.0005104166666
plt.colorbar(format="%+2.0f dB")
plt.show()

# %% [markdown]
# Auch im Spektrogram ist das knacken deutlich zu sehen, da es sich am Ende und am Anfang des Signals über viele Frequenzbereiche hinwegzieht.
# ## Trainingsdaten erzeugen

# %%
from PIL import Image
from matplotlib.pyplot import imshow
import os
import glob

def generate_new_echo(fs=96000,duration=0.1,f=25000):
    time.sleep(1)
    sine = (np.sin(2*np.pi*np.arange(fs*duration)*f/fs)).astype(np.float32)
    samples=np.concatenate((sine, [0]*int(fs*duration)*2), axis=None)
    
    for i in range(2):
        samples=np.concatenate((samples, sine), axis=None)
        samples=np.concatenate((samples, [0]*int(fs*duration*2)), axis=None)


    rec=sd.playrec(samples,fs,channels=1)
    rec=rec.reshape((samples.shape[0]))[60050:87000]
    time.sleep(1)
    return rec

def get_next_img_name(path):
    maxindex=0
    for x in glob.glob(path+"*.png"):
        index=int(x.split("/")[-1].split(".")[0])
        if index>=maxindex:
            maxindex=index
    return path+str(maxindex+1)+".png"
    
def img_from_audio(rec,label):
    path = "data/"+str(label)+"/"
    try:os.mkdir("data")
    except OSError:print ()
    try:os.mkdir(path)
    except OSError:print ()

    
    
    D=np.abs(librosa.stft(rec,n_fft=2048,hop_length=64))
    DB=librosa.amplitude_to_db(D,ref=np.max)
    
    
    img=np.interp(DB[250:600,:400], (DB[250:600,:400].min(), DB[250:600,:400].max()), (0, 255))
    img = Image.fromarray(np.uint8(img) , 'L')
    img_path=get_next_img_name(path)
    img.save(img_path)
    print(img_path+" gespeichert!")
    #imshow(img,cmap='gray')
    #plt.axis('off')

# %%
time.sleep(15)
for i in range(100):
    img_from_audio(generate_new_echo(),label="wohnzimmer")
# Out:
# data/wohnzimmer/1.png gespeichert!
#
#
# data/wohnzimmer/2.png gespeichert!
#
#
# data/wohnzimmer/3.png gespeichert!
#
#
# data/wohnzimmer/4.png gespeichert!
#
#
# data/wohnzimmer/5.png gespeichert!
#
#
# data/wohnzimmer/6.png gespeichert!
#
#
# data/wohnzimmer/7.png gespeichert!
#
#
# data/wohnzimmer/8.png gespeichert!
#
#
# data/wohnzimmer/9.png gespeichert!
#
#
# data/wohnzimmer/10.png gespeichert!
#
#
# data/wohnzimmer/11.png gespeichert!
#
#
# data/wohnzimmer/12.png gespeichert!
#
#
# data/wohnzimmer/13.png gespeichert!
#
#
# data/wohnzimmer/14.png gespeichert!
#
#
# data/wohnzimmer/15.png gespeichert!
#
#
# data/wohnzimmer/16.png gespeichert!
#
#
# data/wohnzimmer/17.png gespeichert!
#
#
# data/wohnzimmer/18.png gespeichert!
#
#
# data/wohnzimmer/19.png gespeichert!
#
#
# data/wohnzimmer/20.png gespeichert!
#
#
# data/wohnzimmer/21.png gespeichert!
#
#
# data/wohnzimmer/22.png gespeichert!
#
#
# data/wohnzimmer/23.png gespeichert!
#
#
# data/wohnzimmer/24.png gespeichert!
#
#
# data/wohnzimmer/25.png gespeichert!
#
#
# data/wohnzimmer/26.png gespeichert!
#
#
# data/wohnzimmer/27.png gespeichert!
#
#
# data/wohnzimmer/28.png gespeichert!
#
#
# data/wohnzimmer/29.png gespeichert!
#
#
# data/wohnzimmer/30.png gespeichert!
#
#
# data/wohnzimmer/31.png gespeichert!
#
#
# data/wohnzimmer/32.png gespeichert!
#
#
# data/wohnzimmer/33.png gespeichert!
#
#
# data/wohnzimmer/34.png gespeichert!
#
#
# data/wohnzimmer/35.png gespeichert!
#
#
# data/wohnzimmer/36.png gespeichert!
#
#
# data/wohnzimmer/37.png gespeichert!
#
#
# data/wohnzimmer/38.png gespeichert!
#
#
# data/wohnzimmer/39.png gespeichert!
#
#
# data/wohnzimmer/40.png gespeichert!
#
#
# data/wohnzimmer/41.png gespeichert!
#
#
# data/wohnzimmer/42.png gespeichert!
#
#
# data/wohnzimmer/43.png gespeichert!
#
#
# data/wohnzimmer/44.png gespeichert!
#
#
# data/wohnzimmer/45.png gespeichert!
#
#
# data/wohnzimmer/46.png gespeichert!
#
#
# data/wohnzimmer/47.png gespeichert!
#
#
# data/wohnzimmer/48.png gespeichert!
#
#
# data/wohnzimmer/49.png gespeichert!
#
#
# data/wohnzimmer/50.png gespeichert!
#
#
# data/wohnzimmer/51.png gespeichert!
#
#
# data/wohnzimmer/52.png gespeichert!
#
#
# data/wohnzimmer/53.png gespeichert!
#
#
# data/wohnzimmer/54.png gespeichert!
#
#
# data/wohnzimmer/55.png gespeichert!
#
#
# data/wohnzimmer/56.png gespeichert!
#
#
# data/wohnzimmer/57.png gespeichert!
#
#
# data/wohnzimmer/58.png gespeichert!
#
#
# data/wohnzimmer/59.png gespeichert!
#
#
# data/wohnzimmer/60.png gespeichert!
#
#
# data/wohnzimmer/61.png gespeichert!
#
#
# data/wohnzimmer/62.png gespeichert!
#
#
# data/wohnzimmer/63.png gespeichert!
#
#
# data/wohnzimmer/64.png gespeichert!
#
#
# data/wohnzimmer/65.png gespeichert!
#
#
# data/wohnzimmer/66.png gespeichert!
#
#
# data/wohnzimmer/67.png gespeichert!
#
#
# data/wohnzimmer/68.png gespeichert!
#
#
# data/wohnzimmer/69.png gespeichert!
#
#
# data/wohnzimmer/70.png gespeichert!
#
#
# data/wohnzimmer/71.png gespeichert!
#
#
# data/wohnzimmer/72.png gespeichert!
#
#
# data/wohnzimmer/73.png gespeichert!
#
#
# data/wohnzimmer/74.png gespeichert!
#
#
# data/wohnzimmer/75.png gespeichert!
#
#
# data/wohnzimmer/76.png gespeichert!
#
#
# data/wohnzimmer/77.png gespeichert!
#
#
# data/wohnzimmer/78.png gespeichert!
#
#
# data/wohnzimmer/79.png gespeichert!
#
#
# data/wohnzimmer/80.png gespeichert!
#
#
# data/wohnzimmer/81.png gespeichert!
#
#
# data/wohnzimmer/82.png gespeichert!
#
#
# data/wohnzimmer/83.png gespeichert!
#
#
# data/wohnzimmer/84.png gespeichert!
#
#
# data/wohnzimmer/85.png gespeichert!
#
#
# data/wohnzimmer/86.png gespeichert!
#
#
# data/wohnzimmer/87.png gespeichert!
#
#
# data/wohnzimmer/88.png gespeichert!
#
#
# data/wohnzimmer/89.png gespeichert!
#
#
# data/wohnzimmer/90.png gespeichert!
#
#
# data/wohnzimmer/91.png gespeichert!
#
#
# data/wohnzimmer/92.png gespeichert!
#
#
# data/wohnzimmer/93.png gespeichert!
#
#
# data/wohnzimmer/94.png gespeichert!
#
#
# data/wohnzimmer/95.png gespeichert!
#
#
# data/wohnzimmer/96.png gespeichert!
#
#
# data/wohnzimmer/97.png gespeichert!
#
#
# data/wohnzimmer/98.png gespeichert!
#
#
# data/wohnzimmer/99.png gespeichert!
#
#
# data/wohnzimmer/100.png gespeichert!

# %% [markdown]
# # Klassifikation

# %%
import tensorflow as tf
from tensorflow import keras
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-188-3d1e6d42ad48> in <module>
# ----> 1 import tensorflow as tf
#       2 from tensorflow import keras
#
# ModuleNotFoundError: No module named 'tensorflow'
